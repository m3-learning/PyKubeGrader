# %%
from pykubegrader.grade_reports.class_grade_report import ClassGradeReport

out = ClassGradeReport().run()

# %%
from bblearn import merge_bb_learn_data

merge_bb_learn_data(
    "~/Downloads/gc_XLSENGR131BCmfs_202425_studinfo_2025-03-18-09-36-47.csv",
    "~/Downloads/output (3).xlsx",
)
# Out:
#             Last Name First Name           Username  Student ID  \
# 0              Abboud        Kam             ka3232  14736537.0
# 1              Afzaal      Tariq              ta669  14738986.0
# 2    Agar_PreviewUser     Joshua  jca92_previewuser         NaN
# 3             Agarwal      Varun              va438  14705074.0
# 4              Akhtar    Fazaima              fa577  14720536.0
# ..                ...        ...                ...         ...
# 303             Zheng   Jonathan              jz898  14720356.0
# 304             Zheng       Nick              nz357  14718936.0
# 305               Zhu     Ylaine              yz922  14718252.0
# 306          Zorrilla    Abraham              az643  13241287.0
# 307               Zou     Rickie              rz365  14705048.0
#
#              Last Access Availability  Child Course ID  \
# 0    2025-03-17 22:45:00          Yes     23948.202425
# 1    2025-03-18 05:28:59          Yes     21543.202425
# ...
